# %% [markdown]
# # Ex. No: 01
# # Image Handling and Pixel Transformations Using OpenCV
#
# *Name:* Gunasundari.B   *Reg. No:*212224040093

# %%
import cv2
import numpy as py
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Read the image as grayscale

# %%
img = cv2.imread('Eagle_in_Flight.jpg', cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 2. Print the image width, height & Channel

# %%
print("Shape:", img.shape)
# Out:
# Shape: (600, 768, 3)

# %% [markdown]
# 3. Display the image using matplotlib imshow().

# %%
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %% [markdown]
# 4. Save the image as a PNG file using OpenCV imwrite().

# %%
cv2.imwrite('Eagle_in_Flight.png', img_gray)
# Out:
# True

# %% [markdown]
# 5. Read the saved image above as a color image using cv2.cvtColor().

# %%
img_color = cv2.imread('Eagle_in_Flight.png')
img_color = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 6. Display the Colour image using matplotlib imshow() & Print the image width, height & channel

# %%
plt.imshow(img_color)
plt.title("Color Image")
plt.axis("off")
plt.show()
print("Color Shape:", img_color.shape)
# Out:
# Color Shape: (600, 768, 3)

# %% [markdown]
# 7. Crop the image to extract any specific (Eagle alone)  object from the image.

# %%
crop = img_rgb[0:450, 200:550]

plt.imshow(crop)
plt.title("Cropped Region")
plt.axis("off")
plt.show()
print("Crop Shape:", crop.shape)
# Out:
# Crop Shape: (450, 350, 3)

# %% [markdown]
# 8. Resize the image up by a factor of 2x.

# %%
res = cv2.resize(crop, None, fx=2, fy=2)

# %% [markdown]
# 9. Flip the cropped/resized image horizontally. (Eagle Image)

# %%
flip = cv2.flip(res, 1)

plt.imshow(flip)
plt.title("Flipped Horizontally")
plt.axis("off")
plt.show()

# %% [markdown]
# 10. Read in the image ('Apollo-11-launch.jpg').

# %%
apollo = cv2.imread('Apollo-11-launch.jpg')
apollo_rgb = cv2.cvtColor(apollo, cv2.COLOR_BGR2RGB)
print("Apollo shape:", apollo_rgb.shape)
# Out:
# Apollo shape: (720, 1280, 3)

# %% [markdown]
# 11. Add the following text to the dark area at the bottom of the image (centered on the image):

# %%
cv2.putText(apollo_rgb,
            "Apollo 11 Saturn V Launch, July 16, 1969",
            (150, apollo_rgb.shape[0]-40),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (255,255,255),
            2)
# Out:
# array([[[213, 213, 213],
#         [213, 213, 213],
#         [210, 210, 210],
#         ...,
#         [241, 241, 241],
#         [240, 240, 240],
#         [241, 241, 241]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [239, 239, 239],
#         [240, 240, 240]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        ...,
#
#        [[ 47,  47,  47],
#         [ 46,  46,  46],
#         [ 42,  42,  42],
#         ...,
#         [ 17,  17,  17],
#         [ 11,  11,  11],
#         [  5,   5,   5]],
#
#        [[ 44,  44,  44],
#         [ 47,  47,  47],
#         [ 47,  47,  47],
#         ...,
#         [ 17,  17,  17],
#         [ 10,  10,  10],
#         [  4,   4,   4]],
#
#        [[ 43,  43,  43],
#         [ 49,  49,  49],
#         [ 52,  52,  52],
# ...

# %% [markdown]
# 12. Draw a magenta rectangle that encompasses the launch tower and the rocket.

# %%
cv2.rectangle(apollo_rgb, (400,100), (800,650), (255,0,255), 3)
# Out:
# array([[[213, 213, 213],
#         [213, 213, 213],
#         [210, 210, 210],
#         ...,
#         [241, 241, 241],
#         [240, 240, 240],
#         [241, 241, 241]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [239, 239, 239],
#         [240, 240, 240]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        ...,
#
#        [[ 47,  47,  47],
#         [ 46,  46,  46],
#         [ 42,  42,  42],
#         ...,
#         [ 17,  17,  17],
#         [ 11,  11,  11],
#         [  5,   5,   5]],
#
#        [[ 44,  44,  44],
#         [ 47,  47,  47],
#         [ 47,  47,  47],
#         ...,
#         [ 17,  17,  17],
#         [ 10,  10,  10],
#         [  4,   4,   4]],
#
#        [[ 43,  43,  43],
#         [ 49,  49,  49],
#         [ 52,  52,  52],
# ...

# %% [markdown]
# 13. Display the final annotated image.

# %%
plt.imshow(apollo_rgb)
plt.title("Annotated Image")
plt.axis("off")
plt.show()

# %% [markdown]
# 14. Read the image ('boy.jpg').

# %%
boy = cv2.imread('boy.jpg')
boy_rgb = cv2.cvtColor(boy, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 15. Adjust the brightness of the image.

# %%
m = np.ones(boy_rgb.shape, dtype="uint8") * 50

# %% [markdown]
# 16. Create brighter and darker images.

# %%
img_brighter = cv2.add(boy_rgb, m)
img_darker = cv2.subtract(boy_rgb, m)

# %% [markdown]
# 17. Display the images (Original Image, Darker Image, Brighter Image).

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,3,1); plt.imshow(boy_rgb); plt.title("Original"); plt.axis("off")
plt.subplot(1,3,2); plt.imshow(img_brighter); plt.title("Brighter"); plt.axis("off")
plt.subplot(1,3,3); plt.imshow(img_darker); plt.title("Darker"); plt.axis("off")
plt.show()

# %% [markdown]
# 18. Modify the image contrast.

# %%
higher1 = cv2.convertScaleAbs(boy_rgb, alpha=1.1, beta=0)
higher2 = cv2.convertScaleAbs(boy_rgb, alpha=1.2, beta=0)

# %% [markdown]
# 19. Display the images (Original, Lower Contrast, Higher Contrast).

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,3,1); plt.imshow(boy_rgb); plt.title("Original"); plt.axis("off")
plt.subplot(1,3,2); plt.imshow(higher1); plt.title("Contrast 1.1x"); plt.axis("off")
plt.subplot(1,3,3); plt.imshow(higher2); plt.title("Contrast 1.2x"); plt.axis("off")
plt.show()

# %% [markdown]
# 20. Split the image (boy.jpg) into the B,G,R components & Display the channels.

# %%
b, g, r = cv2.split(boy)

plt.figure(figsize=(10,5))
plt.subplot(1,3,1); plt.imshow(b, cmap='gray'); plt.title("Blue"); plt.axis("off")
plt.subplot(1,3,2); plt.imshow(g, cmap='gray'); plt.title("Green"); plt.axis("off")
plt.subplot(1,3,3); plt.imshow(r, cmap='gray'); plt.title("Red"); plt.axis("off")
plt.show()

# %% [markdown]
# 21. _merged the R, G, B , display along with orginal image

# %%
merged_rgb = cv2.merge([r,g,b])
plt.imshow(merged_rgb)
plt.title("Merged RGB")
plt.axis("off")
plt.show()

# %% [markdown]
# 22. Split the image into the H, S, V components &  Display the channels.

# %%
hsv_img = cv2.cvtColor(boy_rgb, cv2.COLOR_RGB2HSV)
h,s,v = cv2.split(hsv_img)

plt.figure(figsize=(10,5))
plt.subplot(1,3,1); plt.imshow(h, cmap='gray'); plt.title("Hue"); plt.axis("off")
plt.subplot(1,3,2); plt.imshow(s, cmap='gray'); plt.title("Saturation"); plt.axis("off")
plt.subplot(1,3,3); plt.imshow(v, cmap='gray'); plt.title("Value"); plt.axis("off")
plt.show()

# %% [markdown]
# 23. _merged the H, S, V, display along with orginal image

# %%
merged_hsv = cv2.cvtColor(cv2.merge([h,s,v]), cv2.COLOR_HSV2RGB)
combined = np.concatenate((boy_rgb, merged_hsv), axis=1)

plt.imshow(combined)
plt.title("Original & HSV Merged")
plt.axis("off")
plt.show()
